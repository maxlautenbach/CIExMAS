# %% [markdown]
# # Setup

# %%
import helper_tools.parser as parser
import importlib
import pandas as pd
import warnings

warnings.filterwarnings("ignore")

importlib.reload(parser)

relation_df, entity_df, docs = parser.synthie_parser("train")
entity_set = entity_df[['entity', 'entity_uri']].drop_duplicates()
predicate_set_df = relation_df[["predicate", "predicate_uri"]].drop_duplicates()
# Out:
# Fetching 27 files:   0%|          | 0/27 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:00<00:00, 27395.85it/s]
# Uploading Entities to Qdrant.
# 100%|██████████| 46/46 [00:06<00:00,  6.91it/s]
# Uploading Predicates to Qdrant.
# 100%|██████████| 29/29 [00:04<00:00,  6.79it/s]

# %%
from langfuse.callback import CallbackHandler
from dotenv import load_dotenv
import os

load_dotenv()
langfuse_handler = CallbackHandler(
    secret_key=os.getenv("LANGFUSE_SECRET_KEY"),
    public_key=os.getenv("LANGFUSE_PUBLIC_KEY"),
    host=os.getenv("LANGFUSE_HOST"),
)

# %%
from langgraph.graph import StateGraph, START, END
from approaches.Supervisor.Gen1.setup import cIEState
from approaches.Supervisor.Gen1.agents.agent_instructor import agent as agent_instructor_agent
from approaches.Supervisor.Gen1.agents.entity_extractor import agent as entity_extraction_agent
from approaches.Supervisor.Gen1.agents.relation_extractor import agent as relation_extraction_agent
from approaches.Supervisor.Gen1.agents.uri_detector import agent as uri_detection_agent
from approaches.Supervisor.Gen1.agents.result_checker import agent as result_checker_agent
from approaches.Supervisor.Gen1.agents.result_formatter import agent as result_formatting_agent
from approaches.Supervisor.Gen1.agents.planner import agent as planner

builder = StateGraph(cIEState)
builder.add_node("planner", planner)
builder.add_node("agent_instructor_agent",agent_instructor_agent)
builder.add_node("entity_extraction_agent", entity_extraction_agent)
builder.add_node("relation_extraction_agent",relation_extraction_agent)
builder.add_node("uri_detection_agent",uri_detection_agent)
builder.add_node("result_checker_agent",result_checker_agent)
builder.add_node("result_formatting_agent",result_formatting_agent)

builder.add_edge(START, "planner")

graph = builder.compile()

# %%
target_doc = docs.iloc[3]
doc_id = target_doc["docid"]
text = target_doc["text"]
text
# Out:
# 'Lambda Mensae is a star in the constellation Mensa. It was discovered by Nicolas-Louis de Lacaille, and named after Table Mountain in South Africa. Mensa shares borders with Chamaeleon and Hydrus.'

# %%
response_state = graph.invoke({"text": text, "results": [], "call_trace": [], "comments": [], "debug": False}, config={"callbacks": [langfuse_handler], "recursion_limit": 100})

# %% [markdown]
# # Pretty Print Response State

# %%
print(f"""cIE for text: {response_state["text"]}

Results:""")
for i, call in enumerate(response_state["call_trace"]):
    print(f"Agent ID: {call[0]}")
    print(f"Instruction: {call[1]}")
    print(f"Result: {response_state['results'][i]}\n\n")
    
print("Agent Comments:")
for comment in response_state["comments"]:
    print(comment)
# Out:
# cIE for text: Ricardo Lumengo is a Swiss politician. He was born in Fribourg and lives in Biel/Bienne. He works in Bern and speaks the Kongo language.
#
# Results:
# Agent ID: entity_extraction_agent
# Instruction: Extract entities from the given text.
# Result: -- Entity Extraction Agent --
#
# Based on the provided text, I will extract the entities as per the instruction. Here is the list of extracted entities:
#
# 1. **Person**: Ricardo Lumengo
# 2. **Nationality**: Swiss
# 3. **Location**:
#    - Fribourg
#    - Biel/Bienne
#    - Bern
# 4. **Language**: Kongo
#
# These entities are extracted from the given text as they represent specific objects, concepts, or individuals mentioned in the text. Let me know if you need further assistance or have any additional instructions.
#
#
# Agent ID: relation_extraction_agent
# Instruction: Extract relations from the text focusing on the entities: Ricardo Lumengo, Swiss, Fribourg, Biel/Bienne, Bern, and Kongo. Disambiguate any potentially ambiguous relations such as "born in," "lives in," and "works in."
# Result: -- Relation Extraction Agent --
#
# Based on the provided text and instruction, I will extract the relations focusing on the specified entities. Here are the extracted triples:
#
# 1. (Ricardo Lumengo, nationality, Swiss)
#    - Alternative predicate: (Ricardo Lumengo, country, Swiss)
#    - Alternative predicate: (Ricardo Lumengo, citizen_of, Switzerland)
#
# 2. (Ricardo Lumengo, birthplace, Fribourg)
#    - Alternative predicate: (Ricardo Lumengo, born_in, Fribourg)
#    - Alternative predicate: (Ricardo Lumengo, place_of_birth, Fribourg)
#
# 3. (Ricardo Lumengo, residence, Biel/Bienne)
#    - Alternative predicate: (Ricardo Lumengo, lives_in, Biel/Bienne)
#    - Alternative predicate: (Ricardo Lumengo, city_of_residence, Biel/Bienne)
#
# 4. (Ricardo Lumengo, workplace, Bern)
#    - Alternative predicate: (Ricardo Lumengo, works_in, Bern)
#    - Alternative predicate: (Ricardo Lumengo, city_of_employment, Bern)
#
# 5. (Ricardo Lumengo, language, Kongo)
#    - Alternative predicate: (Ricardo Lumengo, speaks, Kongo)
#    - Alternative predicate: (Ricardo Lumengo, native_language, Kongo)
#
# Note that I have disambiguated the relations as per the instruction and provided alternative predicates where applicable. The extracted triples are based on the provided text and focus on the specified entities.
#
# Here is the complete list of extracted triples in a simple format:
#
# - Ricardo Lumengo, nationality, Swiss
# - Ricardo Lumengo, country, Swiss
# - Ricardo Lumengo, citizen_of, Switzerland
# - Ricardo Lumengo, birthplace, Fribourg
# - Ricardo Lumengo, born_in, Fribourg
# - Ricardo Lumengo, place_of_birth, Fribourg
# - Ricardo Lumengo, residence, Biel/Bienne
# - Ricardo Lumengo, lives_in, Biel/Bienne
# - Ricardo Lumengo, city_of_residence, Biel/Bienne
# - Ricardo Lumengo, workplace, Bern
# - Ricardo Lumengo, works_in, Bern
# - Ricardo Lumengo, city_of_employment, Bern
# - Ricardo Lumengo, language, Kongo
# - Ricardo Lumengo, speaks, Kongo
# - Ricardo Lumengo, native_language, Kongo
#
#
# Agent ID: uri_detection_agent
# Instruction: Ricardo Lumengo[LABEL], Swiss[LABEL], Fribourg[LABEL], Biel/Bienne[LABEL], Bern[LABEL], Kongo[LABEL], nationality[DESCR], birthplace[DESCR], residence[DESCR], workplace[DESCR], language[DESCR]
# Result: Output of uri_detection_agent: After analyzing the responses from the URI detection tool, I've compiled an overall mapping of search terms to URIs. Here are the results:
#
# * Ricardo Lumengo: http://www.wikidata.org/entity/Q677663
# * Swiss: http://www.wikidata.org/entity/Q39
# * Fribourg: http://www.wikidata.org/entity/Q36378
# * Biel/Bienne: http://www.wikidata.org/entity/Q1034
# * Bern: http://www.wikidata.org/entity/Q70
# * Kongo: http://www.wikidata.org/entity/Q33702 (note: this refers to the Kongo language, not the country or region)
#
# The following search terms did not yield a direct match in the knowledge graph:
# * nationality: This term is related to several concepts, including "place of origin (Switzerland)" (http://www.wikidata.org/entity/P1321) and "country of citizenship" (http://www.wikidata.org/entity/P27). However, there is no single URI that directly represents the concept of nationality.
# * birthplace: This term is related to several concepts, including "place of origin (Switzerland)" (http://www.wikidata.org/entity/P1321) and "residence" (http://www.wikidata.org/entity/P551). However, there is no single URI that directly represents the concept of birthplace.
# * residence: This term is related to the concept of "residence" (http://www.wikidata.org/entity/P551), but it's not clear if this is the intended meaning.
# * workplace: This term is related to the concept of "work location" (http://www.wikidata.org/entity/P937), but it's not clear if this is the intended meaning.
# * language: This term is related to the concept of "languages spoken, written or signed" (http://www.wikidata.org/entity/P1412), but it's not clear if this is the intended meaning.
#
# These non-matching search terms might not be present in the knowledge graph, or they might be represented by more specific or related concepts. Further clarification or context may be needed to provide a more accurate mapping.
#
#
# Agent ID: entity_extraction_agent
# Instruction: Extract more specific types for the locations (Fribourg, Biel/Bienne, Bern) and disambiguate any potentially ambiguous entities, focusing on clarifying the intended meanings of terms like "residence" and "workplace".
# Result: -- Entity Extraction Agent --
#
# Based on the provided text and instruction, I will extract the entities and provide more specific types for the locations, disambiguating any potentially ambiguous entities.
#
# The extracted entities are:
#
# 1. **Ricardo Lumengo**: Person, specifically a Swiss politician
# 2. **Fribourg**: City, specifically the place of birth
# 3. **Biel/Bienne**: City, specifically the residence (place of living)
# 4. **Bern**: City, specifically the workplace
# 5. **Switzerland**: Country (implied by "Swiss politician", although not explicitly mentioned)
# 6. **Kongo language**: Language
#
# To provide more specific types for the locations and disambiguate any potentially ambiguous entities:
#
# * **Fribourg** is a city in Switzerland, and in this context, it refers to the place where Ricardo Lumengo was born.
# * **Biel/Bienne** is a city in Switzerland, and in this context, it refers to Ricardo Lumengo's residence, meaning the place where he lives.
# * **Bern** is the capital city of Switzerland, and in this context, it refers to Ricardo Lumengo's workplace, meaning the place where he works.
#
# By clarifying the intended meanings of terms like "residence" and "workplace", we can conclude that:
#
# * **Residence**: Biel/Bienne (the place where Ricardo Lumengo lives)
# * **Workplace**: Bern (the place where Ricardo Lumengo works)
# * **Place of birth**: Fribourg (the place where Ricardo Lumengo was born)
#
# These extracted entities and disambiguated locations provide a clearer understanding of the information provided in the text.
#
#
# Agent ID: relation_extraction_agent
# Instruction: Extract relations from the text, focusing on the disambiguated entities (Ricardo Lumengo, Fribourg, Biel/Bienne, Bern, Swiss, Kongo language) and locations, and provide alternative predicates where applicable. The agent should consider the more specific types for the locations (Fribourg, Biel/Bienne, Bern) extracted by the Entity Extraction Agent.
# Result: -- Relation Extraction Agent --
#
# Based on the provided text and instruction, I will extract the relations and provide alternative predicates where applicable. Here is the list of extracted triples:
#
# 1. (Ricardo Lumengo, nationality, Swiss)
# 	* Alternative predicate: (Ricardo Lumengo, country, Switzerland)
# 2. (Ricardo Lumengo, birthplace, Fribourg)
# 	* Alternative predicate: (Ricardo Lumengo, born in, Fribourg)
# 	* More specific type: (Ricardo Lumengo, born in, Fribourg city)
# 3. (Ricardo Lumengo, residence, Biel/Bienne)
# 	* Alternative predicate: (Ricardo Lumengo, lives in, Biel/Bienne)
# 	* More specific type: (Ricardo Lumengo, lives in, Biel/Bienne city)
# 4. (Ricardo Lumengo, workplace, Bern)
# 	* Alternative predicate: (Ricardo Lumengo, works in, Bern)
# 	* More specific type: (Ricardo Lumengo, works in, Bern city)
# 5. (Ricardo Lumengo, language spoken, Kongo language)
# 	* Alternative predicate: (Ricardo Lumengo, speaks, Kongo language)
# 6. (Fribourg, located in, Switzerland)
# 	* Alternative predicate: (Fribourg, country, Switzerland)
# 	* More specific type: (Fribourg, located in, Swiss canton)
# 7. (Biel/Bienne, located in, Switzerland)
# 	* Alternative predicate: (Biel/Bienne, country, Switzerland)
# 	* More specific type: (Biel/Bienne, located in, Swiss canton)
# 8. (Bern, located in, Switzerland)
# 	* Alternative predicate: (Bern, country, Switzerland)
# 	* More specific type: (Bern, located in, Swiss canton)
#
# Note that I have considered the more specific types for the locations (Fribourg, Biel/Bienne, Bern) as cities, and also provided alternative predicates for each relation. Additionally, I have extracted the relations between the locations and Switzerland, as well as the relation between Ricardo Lumengo and the Kongo language.
#
#
# Agent ID: uri_detection_agent
# Instruction: Ricardo Lumengo[LABEL], Fribourg[LABEL], Biel/Bienne[LABEL], Bern[LABEL], Swiss[LABEL], Kongo language[LABEL], nationality[DESCR], birthplace[DESCR], residence[DESCR], workplace[DESCR], language[DESCR]
# Result: Output of uri_detection_agent: After analyzing the response from the URI detection tool, I have identified the following mappings of search terms to URIs:
#
# * Ricardo Lumengo: http://www.wikidata.org/entity/Q677663
# * Fribourg: http://www.wikidata.org/entity/Q36378
# * Biel/Bienne: http://www.wikidata.org/entity/Q1034
# * Bern: http://www.wikidata.org/entity/Q70
# * Kongo language: http://www.wikidata.org/entity/Q33702
#
# The following search terms do not have a direct mapping to a URI:
# * Swiss: This term is related to the country Switzerland, which has a URI of http://www.wikidata.org/entity/Q39. However, the term "Swiss" is not a direct match to a URI.
# * Nationality: This term is related to the concept of citizenship or nationality, but it does not have a direct mapping to a URI. The closest match is the property "country of citizenship" with URI http://www.wikidata.org/entity/P27.
# * Birthplace: This term is related to the concept of place of birth, but it does not have a direct mapping to a URI. The closest match is the property "place of origin (Switzerland)" with URI http://www.wikidata.org/entity/P1321, but this is not a direct match.
# * Residence: This term has a direct mapping to the property "residence" with URI http://www.wikidata.org/entity/P551.
# * Workplace: This term has a direct mapping to the property "work location" with URI http://www.wikidata.org/entity/P937.
# * Language: This term has a direct mapping to the property "languages spoken, written or signed" with URI http://www.wikidata.org/entity/P1412.
#
# Note that some of these terms may not have a direct mapping to a URI because they are not specific enough or because they are related to concepts that are not directly represented in the knowledge graph.
#
# Here is the overall mapping of search terms to URIs in a JSON format:
#
# ```
# {
#   "Ricardo Lumengo": "http://www.wikidata.org/entity/Q677663",
#   "Fribourg": "http://www.wikidata.org/entity/Q36378",
#   "Biel/Bienne": "http://www.wikidata.org/entity/Q1034",
#   "Bern": "http://www.wikidata.org/entity/Q70",
#   "Kongo language": "http://www.wikidata.org/entity/Q33702",
#   "Residence": "http://www.wikidata.org/entity/P551",
#   "Workplace": "http://www.wikidata.org/entity/P937",
#   "Language": "http://www.wikidata.org/entity/P1412"
# }
# ```
#
# The non-mapping search terms with advice are:
#
# * Swiss: This term might not be present in the knowledge graph as a separate entity, but it is related to the country Switzerland with URI http://www.wikidata.org/entity/Q39.
# * Nationality: This term might not be present in the knowledge graph as a separate entity, but it is related to the concept of citizenship or nationality with property "country of citizenship" and URI http://www.wikidata.org/entity/P27.
# * Birthplace: This term might not be present in the knowledge graph as a separate entity, but it is related to the concept of place of birth with property "place of origin (Switzerland)" and URI http://www.wikidata.org/entity/P1321.
#
#
# Agent ID: result_formatting_agent
# Instruction:
# Result:
# <http://www.wikidata.org/entity/Q677663> <http://www.wikidata.org/entity/P27> <http://www.wikidata.org/entity/Q39> .
# <http://www.wikidata.org/entity/Q677663> <http://www.wikidata.org/entity/P19> <http://www.wikidata.org/entity/Q36378> .
# <http://www.wikidata.org/entity/Q677663> <http://www.wikidata.org/entity/P551> <http://www.wikidata.org/entity/Q1034> .
# <http://www.wikidata.org/entity/Q677663> <http://www.wikidata.org/entity/P937> <http://www.wikidata.org/entity/Q70> .
# <http://www.wikidata.org/entity/Q677663> <http://www.wikidata.org/entity/P1412> <http://www.wikidata.org/entity/Q33702> .
# <http://www.wikidata.org/entity/Q36378> <http://www.wikidata.org/entity/P17> <http://www.wikidata.org/entity/Q39> .
# <http://www.wikidata.org/entity/Q1034> <http://www.wikidata.org/entity/P17> <http://www.wikidata.org/entity/Q39> .
# <http://www.wikidata.org/entity/Q70> <http://www.wikidata.org/entity/P17> <http://www.wikidata.org/entity/Q39> .
#
#
#
# Agent Comments:
#
# -- Planner Agent --
# **Full Plan:**
# 1. Extract entities from the input text using the Entity Extraction Agent.
# 2. Disambiguate extracted entities and identify their types.
# 3. Extract relations from the input text using the Relation Extraction Agent.
# 4. Disambiguate extracted relations.
# 5. Use the URI Detection Agent to map entities and relations to the Knowledge Graph.
# 6. Format the results into triples using the Result Formatting Agent.
#
# **Next Step:**
# Call the Entity Extraction Agent to extract entities from the input text.
#
# **Reasoning:**
# The first step is to identify the entities in the text, which will serve as the foundation for further processing. The Entity Extraction Agent is best suited for this task due to its expertise in entities within knowledge graphs.
#
# -- Result Checker Agent --
# To further refine the extraction process, the Relation Extraction Agent should be called to identify the relationships between the extracted entities, such as "born in," "lives in," and "works in." Additionally, consider instructing the Relation Extraction Agent to disambiguate any potentially ambiguous relations. The Entity Extraction Agent has already been called, so the next logical step is to extract relations to understand how the entities interact.
#
# -- Planner Agent --
# - Feedback Review: The Result Checker Agent suggests calling the Relation Extraction Agent to identify relationships between extracted entities and to disambiguate potentially ambiguous relations.
# - Next Step: Call the Relation Extraction Agent to extract relations from the input text, with additional instructions to disambiguate any potentially ambiguous relations.
# - Reasoning: With entities extracted, the next logical step is to understand how these entities interact, which can be achieved by extracting relations such as "born in," "lives in," and "works in," and ensuring any ambiguity in these relations is resolved.
#
# -- Result Checker Agent --
# To further improve the extraction process, the URI Detection Agent should be called to map the extracted entities and relations to the Knowledge Graph, ensuring that the correct URIs are assigned to each entity and relation. This step is crucial for maintaining consistency and accuracy within the Knowledge Graph. Additionally, consider instructing the URI Detection Agent to handle any potential duplicates or ambiguities that may arise during the mapping process.
#
# -- Planner Agent --
# - Feedback Review: The Result Checker Agent suggests calling the URI Detection Agent to map the extracted entities and relations to the Knowledge Graph, ensuring correct URIs are assigned and handling potential duplicates or ambiguities.
# - Next Step: Call the URI Detection Agent to map the extracted entities (Ricardo Lumengo, Swiss, Fribourg, Biel/Bienne, Bern, Kongo) and relations to the Knowledge Graph, with instructions to handle duplicates or ambiguities.
# - Reasoning: Mapping entities and relations to the Knowledge Graph is crucial for consistency and accuracy, and the URI Detection Agent is best suited for this task, ensuring that each entity and relation is correctly represented within the graph.
#
# -- Result Checker Agent --
# To further refine the mapping of entities and relations to the Knowledge Graph, the Entity Extraction Agent should be called again with additional instructions to extract more specific types for the locations (Fribourg, Biel/Bienne, Bern) and to disambiguate any potentially ambiguous entities. This step can help clarify the intended meanings of terms like "residence" and "workplace" and ensure accurate mapping to the Knowledge Graph.
#
# -- Planner Agent --
# - Feedback Review: The Result Checker Agent suggests calling the Entity Extraction Agent again with additional instructions to extract more specific types for the locations (Fribourg, Biel/Bienne, Bern) and to disambiguate any potentially ambiguous entities.
# - Next Step: Call the Entity Extraction Agent to extract more specific types for the locations (Fribourg, Biel/Bienne, Bern) and disambiguate any potentially ambiguous entities, focusing on clarifying the intended meanings of terms like "residence" and "workplace".
# - Reasoning: Refining the extraction of location types and disambiguating entities will help ensure accurate mapping to the Knowledge Graph, particularly for terms that may have multiple meanings or representations within the graph.
#
# -- Result Checker Agent --
# Call the Relation Extraction Agent again to extract relations from the text, focusing on the disambiguated entities and locations, and provide alternative predicates where applicable. This step can help clarify the intended meanings of terms like "residence" and "workplace" and ensure accurate mapping to the Knowledge Graph. Additionally, instruct the Relation Extraction Agent to consider the more specific types for the locations (Fribourg, Biel/Bienne, Bern) extracted by the Entity Extraction Agent.
#
# -- Planner Agent --
# - Feedback Review: The Result Checker Agent suggests calling the Relation Extraction Agent again to extract relations from the text, focusing on the disambiguated entities and locations, and providing alternative predicates where applicable.
#
# - Next Step: Call the Relation Extraction Agent to extract relations from the text, focusing on the disambiguated entities (Ricardo Lumengo, Fribourg, Biel/Bienne, Bern, Swiss, Kongo language) and locations, and provide alternative predicates where applicable. The agent should consider the more specific types for the locations (Fribourg, Biel/Bienne, Bern) extracted by the Entity Extraction Agent.
#
# - Reasoning: With the entities and their types refined, and the locations disambiguated, the next logical step is to re-extract relations to ensure that the interactions between these entities are accurately captured, considering the specific contexts of "residence," "workplace," and "place of birth." This will help in creating a comprehensive and accurate set of triples for the Knowledge Graph.
#
# -- Result Checker Agent --
# Call the URI Detection Agent again to map the refined entities and relations to the Knowledge Graph, focusing on accurately representing the disambiguated locations (Fribourg, Biel/Bienne, Bern) and their relationships to Ricardo Lumengo and Switzerland.
#
# -- Planner Agent --
# ## Step 1: Feedback Review
# The Result Checker Agent suggests calling the URI Detection Agent again to map the refined entities and relations to the Knowledge Graph, focusing on accurately representing the disambiguated locations (Fribourg, Biel/Bienne, Bern) and their relationships to Ricardo Lumengo and Switzerland.
#
# ## Step 2: Next Step
# Call the URI Detection Agent to map the refined entities (Ricardo Lumengo, Fribourg, Biel/Bienne, Bern, Swiss, Kongo language) and relations to the Knowledge Graph, with instructions to handle duplicates or ambiguities, especially for terms like "residence," "workplace," and ensuring accurate representation of the locations as cities within Switzerland.
#
# ## Step 3: Reasoning
# With the entities and their types refined, and the locations disambiguated, the next logical step is to ensure that these entities and their relations are accurately mapped to the Knowledge Graph. This involves using the URI Detection Agent to assign the correct URIs to each entity and relation, considering the specific contexts provided by the disambiguation process. This step is crucial for maintaining consistency and accuracy within the Knowledge Graph, especially for terms that may have multiple meanings or representations within the graph.
#
# ## Step 4: Finalizing the Plan
# After the URI Detection Agent has mapped the entities and relations to the Knowledge Graph, the next step will be to call the Result Formatting Agent to summarize the results and output the final triples, thus completing the process of transforming the input text into the desired triple format for closed information extraction using the underlying Knowledge Graph.
#
# -- Result Checker Agent --
# Call the Result Formatting Agent to summarize the results and output the final triples, as the entities and relations have been sufficiently refined and mapped to the Knowledge Graph.
#
# -- Planner Agent --
# ## Step 1: Feedback Review
# The Result Checker Agent suggests calling the Result Formatting Agent to summarize the results and output the final triples, as the entities and relations have been sufficiently refined and mapped to the Knowledge Graph.
#
# ## Step 2: Next Step
# Call the Result Formatting Agent to summarize the results, output the final triples, and end the iteration process. The agent should use the mappings provided by the URI Detection Agent to ensure accurate and consistent representation of entities and relations in the Knowledge Graph.
#
# ## Step 3: Reasoning
# With the entities and relations refined, and the locations disambiguated, the next logical step is to finalize the process by formatting the results into triples. This involves using the Result Formatting Agent to create a comprehensive and accurate set of triples that represent the information extracted from the input text, utilizing the mappings to URIs in the Knowledge Graph to maintain consistency and accuracy.

# %% [markdown]
# # Evaluation

# %%
from helper_tools.evaluation import parse_turtle, evaluate, get_uri_labels

# %%
turtle_string = response_state["results"][-1]
pred_relation_df, error = parse_turtle(turtle_string)
doc_relation_df = relation_df[relation_df["docid"] == doc_id][["subject_uri", "predicate_uri", "object_uri"]]
correct_relation_df = pred_relation_df.merge(doc_relation_df[["subject_uri", "predicate_uri", "object_uri"]], on=["subject_uri", "predicate_uri", "object_uri"], how="inner")

# %%
get_uri_labels(pred_relation_df)
# Out:
#                               subject_uri  \
# 0  http://www.wikidata.org/entity/Q677663
# 1  http://www.wikidata.org/entity/Q677663
# 2      http://www.wikidata.org/entity/Q70
# 3    http://www.wikidata.org/entity/Q1034
# 4  http://www.wikidata.org/entity/Q677663
# 5  http://www.wikidata.org/entity/Q677663
# 6  http://www.wikidata.org/entity/Q677663
# 7   http://www.wikidata.org/entity/Q36378
#
#                           predicate_uri  \
# 0   http://www.wikidata.org/entity/P937
# 1    http://www.wikidata.org/entity/P27
# 2    http://www.wikidata.org/entity/P17
# 3    http://www.wikidata.org/entity/P17
# 4    http://www.wikidata.org/entity/P19
# 5  http://www.wikidata.org/entity/P1412
# 6   http://www.wikidata.org/entity/P551
# 7    http://www.wikidata.org/entity/P17
#
#                               object_uri          subject  \
# 0     http://www.wikidata.org/entity/Q70  Ricardo_Lumengo
# 1     http://www.wikidata.org/entity/Q39  Ricardo_Lumengo
# 2     http://www.wikidata.org/entity/Q39             Bern
# 3     http://www.wikidata.org/entity/Q39      Biel/Bienne
# 4  http://www.wikidata.org/entity/Q36378  Ricardo_Lumengo
# 5  http://www.wikidata.org/entity/Q33702  Ricardo_Lumengo
# 6   http://www.wikidata.org/entity/Q1034  Ricardo_Lumengo
# 7     http://www.wikidata.org/entity/Q39         Fribourg
#
#                              predicate          object
# 0                        work location            Bern
# 1               country of citizenship     Switzerland
# 2                              country     Switzerland
# 3                              country     Switzerland
# 4                              Unknown        Fribourg
# 5  languages spoken, written or signed  Kongo_language
# 6                            residence     Biel/Bienne
# 7                              country     Switzerland

# %%
get_uri_labels(doc_relation_df)
# Out:
#                               subject_uri  \
# 0  http://www.wikidata.org/entity/Q677663
# 1  http://www.wikidata.org/entity/Q677663
# 2  http://www.wikidata.org/entity/Q677663
# 3  http://www.wikidata.org/entity/Q677663
# 4  http://www.wikidata.org/entity/Q677663
#
#                           predicate_uri  \
# 0  http://www.wikidata.org/entity/P1321
# 1    http://www.wikidata.org/entity/P27
# 2   http://www.wikidata.org/entity/P551
# 3   http://www.wikidata.org/entity/P937
# 4  http://www.wikidata.org/entity/P1412
#
#                               object_uri          subject  \
# 0  http://www.wikidata.org/entity/Q36378  Ricardo_Lumengo
# 1     http://www.wikidata.org/entity/Q39  Ricardo_Lumengo
# 2   http://www.wikidata.org/entity/Q1034  Ricardo_Lumengo
# 3     http://www.wikidata.org/entity/Q70  Ricardo_Lumengo
# 4  http://www.wikidata.org/entity/Q33702  Ricardo_Lumengo
#
#                              predicate          object
# 0        place of origin (Switzerland)        Fribourg
# 1               country of citizenship     Switzerland
# 2                            residence     Biel/Bienne
# 3                        work location            Bern
# 4  languages spoken, written or signed  Kongo_language

# %%
get_uri_labels(correct_relation_df)
# Out:
#                               subject_uri  \
# 0  http://www.wikidata.org/entity/Q677663
# 1  http://www.wikidata.org/entity/Q677663
# 2  http://www.wikidata.org/entity/Q677663
# 3  http://www.wikidata.org/entity/Q677663
#
#                           predicate_uri  \
# 0   http://www.wikidata.org/entity/P937
# 1    http://www.wikidata.org/entity/P27
# 2  http://www.wikidata.org/entity/P1412
# 3   http://www.wikidata.org/entity/P551
#
#                               object_uri          subject  \
# 0     http://www.wikidata.org/entity/Q70  Ricardo_Lumengo
# 1     http://www.wikidata.org/entity/Q39  Ricardo_Lumengo
# 2  http://www.wikidata.org/entity/Q33702  Ricardo_Lumengo
# 3   http://www.wikidata.org/entity/Q1034  Ricardo_Lumengo
#
#                              predicate          object
# 0                        work location            Bern
# 1               country of citizenship     Switzerland
# 2  languages spoken, written or signed  Kongo_language
# 3                            residence     Biel/Bienne

# %%
evaluate(turtle_string, doc_id, relation_df)
# Out:
# (0.5, 0.8, 0.6153846153846154)

# %% [markdown]
# # Evaluation on Test

# %%
evaluation_df = []

# %%
i = 9
target_doc = docs.iloc[i]
doc_id = target_doc["docid"]
text = target_doc["text"]
print(f"doc: {doc_id} - text: {text}")
response = graph.invoke({"text": text, "results": [], "call_trace": [], "comments": [], "debug": False}, config={"callbacks": [langfuse_handler], "recursion_limit": 100})
evaluation_df.append([doc_id, *evaluate(response["results"][-1], doc_id, relation_df)])
# Out:
# doc: 9 - text: Mohsin Siddiqui is a Pakistani politician who is a member of the Muttahida Qaumi Movement, a secular political party.

# %%
evaluation_df = pd.DataFrame(evaluation_df, columns=["docid", "precision", "recall", "f1_score"])
evaluation_df
# Out:
#    docid  precision  recall  f1_score
# 0      0   0.500000    0.50  0.500000
# 1      1   0.500000    0.80  0.615385
# 2      2   0.250000    0.25  0.250000
# 3      4   0.166667    1.00  0.285714
# 4      5   0.000000    0.00  0.000000
# 5      6   0.000000    0.00  0.000000
# 6      7   0.200000    0.25  0.222222
# 7      8   0.000000    0.00  0.000000
# 8      9   0.500000    0.20  0.285714
# 9      3   0.000000    0.00  0.000000

# %%
print(f'F1 (Macro Avg.): {evaluation_df["f1_score"].mean()}')
print(f'Precision (Macro Avg.): {evaluation_df["precision"].mean()}')
print(f'Recall (Macro Avg.): {evaluation_df["recall"].mean()}')
# Out:
# F1 (Macro Avg.): 0.21590354090354089
# Precision (Macro Avg.): 0.21166666666666661
# Recall (Macro Avg.): 0.3
